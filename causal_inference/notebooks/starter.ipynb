# %%
# Cell 1: Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import networkx as nx

# %%
# Cell 2: Title
print("Welcome to Causal Inference 🧠")
# Out:
# Welcome to Causal Inference 🧠

# %%
# Cell 3: Placeholder for DAG visualisation
G = nx.DiGraph()
G.add_edges_from([("X", "Y"), ("Z", "Y")])
nx.draw(G, with_labels=True, node_color='lightblue', node_size=2000, font_size=12)
plt.title("Simple DAG")
plt.show()

# %%
# Load and explore dataset
df = pd.read_csv("../data/student_scores.csv")
print(df.head())

# Simple scatter plot
plt.scatter(df["study_hours"], df["score"], c=df["prep_course"], cmap="coolwarm", label="Score")
plt.xlabel("Study Hours")
plt.ylabel("Score")
plt.title("Study Hours vs Score (Prep Course Highlighted)")
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[14], line 2
#       1 # Load and explore dataset
# ----> 2 df = pd.read_csv("../data/student_scores.csv")
#       3 print(df.head())
#       5 # Simple scatter plot
#
# ...
